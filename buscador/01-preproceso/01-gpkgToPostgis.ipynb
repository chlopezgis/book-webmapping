# %% [markdown]
# # **Importar datos a PostGIS**
#
# ## **1. Crear BD Espacial**
#
# Crearemos la BD `geocoding`. Usaremos la opción `-T` para crear la base de datos a partir de la plantilla **`postgis`**, ademas indicaremos la opción `-w` para no solicitar la contraseña:

# %%
# !createdb -U clopez -w geocoding -T postgis

# %% [markdown]
# Verificar que se creo la base de datos

# %%
# !psql -U clopez -l | grep -i 'geocoding'
# Out:
#  geocoding | clopez   | UTF8         | libc                | es_ES.UTF-8 | es_ES.UTF-8 |                        |             |

# %% [markdown]
# Ahora, vamos a dar persmisos en el esquema postgis y agregar al buscador de rutas el nombre del esquema **postgis**

# %%
# !psql -U clopez -d geocoding -c "GRANT USAGE ON SCHEMA postgis TO public"
# Out:
# GRANT

# %%
# !psql -d geocoding \
 -c "ALTER DATABASE geocoding \
     SET search_path=public,postgis,contrib"
# Out:
# ALTER DATABASE

# %% [markdown]
# ## **2. Importar datos**
#
# Primero crearemos un esquema donde importaremos la información:

# %%
# !psql -U clopez -d geocoding \
 -c "CREATE SCHEMA cartografia"
# Out:
# CREATE SCHEMA

# %% [markdown]
# **Explorar los datos**

# %%
# !ogrinfo /home/clopez/Documentos/data/Gas/gas.gpkg -al -so -nomd | grep -E 'Layer name|Feature Count'
# Out:
# Layer name: puerta
# Feature Count: 2458235
# Layer name: clientes_dep
# Feature Count: 1067373
# Layer name: barrios
# Feature Count: 11528
# Layer name: manzanas_dep
# Feature Count: 143418
# Layer name: ejes_viales
# Feature Count: 386542

# %% [markdown]
# ### **2.1 Importar clientes**

# %%
# !ogr2ogr -f PostgreSQL -a_srs EPSG:4326 \
 PG:"dbname=geocoding user=clopez" \
 -lco GEOMETRY_NAME=geom \
 -lco SCHEMA=cartografia \
 -lco SPATIAL_INDEX=GIST \
 -nln clientes \
 -nlt POINT \
 /home/clopez/Documentos/data/Gas/gas.gpkg clientes_dep

# %% [markdown]
# ### **2.2. Importar barrios**

# %%
# !ogr2ogr -f PostgreSQL -a_srs EPSG:4326 \
 PG:"dbname=geocoding user=clopez" \
 -lco GEOMETRY_NAME=geom \
 -lco SCHEMA=cartografia \
 -lco SPATIAL_INDEX=GIST \
 -nln barrios \
 -nlt POLYGON \
 /home/clopez/Documentos/data/Gas/gas.gpkg barrios

# %% [markdown]
# ### **2.3. Importar manzanas**

# %%
# !ogr2ogr -f PostgreSQL -a_srs EPSG:4326 \
 PG:"dbname=geocoding user=clopez" \
 -lco GEOMETRY_NAME=geom \
 -lco SCHEMA=cartografia \
 -lco SPATIAL_INDEX=GIST \
 -nln manzanas \
 -nlt POLYGON \
 /home/clopez/Documentos/data/Gas/gas.gpkg manzanas_dep

# %% [markdown]
# ### **2.4. Importar calles**

# %%
# !ogr2ogr -f PostgreSQL -a_srs EPSG:4326 \
 PG:"dbname=geocoding user=clopez" \
 -lco GEOMETRY_NAME=geom \
 -lco SCHEMA=cartografia \
 -lco SPATIAL_INDEX=GIST \
 -nln ejes_viales \
 -nlt MULTILINESTRING \
 /home/clopez/Documentos/data/Gas/gas.gpkg ejes_viales

# %% [markdown]
# ### **2.5. Importar puertas**

# %%
# !ogrinfo /home/clopez/Documentos/data/Gas/gas.gpkg puerta -al -so -nomd
# Out:
# INFO: Open of `/home/clopez/Documentos/data/Gas/gas.gpkg'
#       using driver `GPKG' successful.
#
# Layer name: puerta
# Geometry: Point
# Feature Count: 2458235
# Extent: (190369.260000, 8550236.785300) - (354418.824500, 8819279.905800)
# Layer SRS WKT:
# PROJCRS["WGS 84 / UTM zone 18S",
#     BASEGEOGCRS["WGS 84",
#         ENSEMBLE["World Geodetic System 1984 ensemble",
#             MEMBER["World Geodetic System 1984 (Transit)"],
#             MEMBER["World Geodetic System 1984 (G730)"],
#             MEMBER["World Geodetic System 1984 (G873)"],
#             MEMBER["World Geodetic System 1984 (G1150)"],
#             MEMBER["World Geodetic System 1984 (G1674)"],
#             MEMBER["World Geodetic System 1984 (G1762)"],
#             MEMBER["World Geodetic System 1984 (G2139)"],
#             MEMBER["World Geodetic System 1984 (G2296)"],
#             ELLIPSOID["WGS 84",6378137,298.257223563,
#                 LENGTHUNIT["metre",1]],
#             ENSEMBLEACCURACY[2.0]],
#         PRIMEM["Greenwich",0,
#             ANGLEUNIT["degree",0.0174532925199433]],
#         ID["EPSG",4326]],
#     CONVERSION["UTM zone 18S",
#         METHOD["Transverse Mercator",
#             ID["EPSG",9807]],
#         PARAMETER["Latitude of natural origin",0,
#             ANGLEUNIT["degree",0.0174532925199433],
#             ID["EPSG",8801]],
#         PARAMETER["Longitude of natural origin",-75,
#             ANGLEUNIT["degree",0.0174532925199433],
#             ID["EPSG",8802]],
#         PARAMETER["Scale factor at natural origin",0.9996,
#             SCALEUNIT["unity",1],
#             ID["EPSG",8805]],
#         PARAMETER["False easting",500000,
#             LENGTHUNIT["metre",1],
#             ID["EPSG",8806]],
#         PARAMETER["False northing",10000000,
#             LENGTHUNIT["metre",1],
#             ID["EPSG",8807]]],
#     CS[Cartesian,2],
#         AXIS["(E)",east,
#             ORDER[1],
#             LENGTHUNIT["metre",1]],
#         AXIS["(N)",north,
#             ORDER[2],
#             LENGTHUNIT["metre",1]],
#     USAGE[
#         SCOPE["Navigation and medium accuracy spatial referencing."],
#         AREA["Between 78°W and 72°W, southern hemisphere between 80°S and equator, onshore and offshore. Argentina. Brazil. Chile. Colombia. Ecuador. Peru."],
#         BBOX[-80,-78,0,-72]],
#     ID["EPSG",32718]]
# Data axis to CRS axis mapping: 1,2
# FID Column = fid
# Geometry Column = geom
# OBJECTID: Integer64 (0.0)
# CODIGOPREDIO: String (50.0)
# NUMEROLOTE: String (4.0)
# ALTURATEXTO: Real (0.0)
# ANGULOTEXTOROTACION: Real (0.0)
# NUMEROPUERTA: String (50.0)
# CODIGODISTRITO: String (6.0)
# CODIGOSEGMENTOVIA: Integer64 (0.0)
# CODIGOMANZANA: Integer64 (0.0)
# CODIGOPUERTA: Integer64 (0.0)
# USUARIOCREACION: String (50.0)
# MAQUINA: String (50.0)
# FECHACREACION: DateTime
# USUARIOMODIFICACION: String (50.0)
# FECHAMODIFICACION: DateTime
# created_user: String (255.0)
# created_date: DateTime
# last_edited_user: String (255.0)
# last_edited_date: DateTime

# %%
# !ogr2ogr -f PostgreSQL -a_srs EPSG:32718 -t_srs EPSG:4326 \
 PG:"dbname=geocoding user=clopez" \
 -lco GEOMETRY_NAME=geom \
 -lco SCHEMA=cartografia \
 -lco SPATIAL_INDEX=GIST \
 -nln apts \
 -nlt POINT \
 -skipfailures \
 /home/clopez/Documentos/data/Gas/gas.gpkg \
 -sql "SELECT OBJECTID as objectid, CODIGOPREDIO as cod_predio, \
              NUMEROLOTE as lote, NUMEROPUERTA as puerta, \
              CODIGODISTRITO as ubigeo, CODIGOSEGMENTOVIA as cod_via, \
              CODIGOMANZANA as cod_mzna, CODIGOPUERTA as cod_puerta, \
              FECHACREACION as created_date, FECHAMODIFICACION as last_edited_date,\
              geom \
        FROM puerta"
# Out:
# ERROR 1: Failed to reproject feature 1610976 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2149068 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2149157 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2149188 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2149190 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2149208 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2149232 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2149234 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2149246 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2150811 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2153108 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2153110 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2153112 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2153114 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2154248 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2154250 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2154251 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2154252 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2154253 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2154273 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2154291 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2154317 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2154319 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2154328 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2154330 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2154331 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2154332 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2154333 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2154334 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2154335 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158480 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158482 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158486 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158508 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158510 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158512 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158519 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158563 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158564 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158566 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158568 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158706 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158711 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158717 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158729 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158731 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158734 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158737 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158757 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158759 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158780 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158782 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158784 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158786 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158803 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158804 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158806 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158838 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158840 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158841 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158842 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158855 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158867 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158868 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158869 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2158903 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2165024 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2165053 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2167959 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2167961 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2167964 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2168002 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2168003 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2168013 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2168015 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2168017 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2168056 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2168057 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2168058 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2168074 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2168076 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2168081 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2168115 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2168116 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2168117 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2168119 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2180777 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2180779 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2192616 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2192618 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2192655 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2192657 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2219016 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2219053 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2219055 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2221827 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2221847 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2221854 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2221886 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2221888 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2221894 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2221896 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2222989 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2222991 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2223106 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2223107 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2223108 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2223109 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2224401 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2224403 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2224405 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2227556 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2227564 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2227571 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2227573 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2227585 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2227587 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2227589 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2227591 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2227593 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2227595 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2227597 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2227652 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2227663 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2264966 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2264968 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2264994 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2272476 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2272477 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2272478 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2272497 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2272500 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2272520 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2272527 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2272583 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2272585 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2277661 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2281314 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2285459 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2298660 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2298662 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2298664 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2298666 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2298668 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2298680 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2298682 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2298685 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2298686 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2321895 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2322221 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2322311 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2322316 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2322330 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2322343 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2322352 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2322587 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2322589 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2323035 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2323083 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2323282 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2323343 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2323345 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2323347 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2323349 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2323351 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2323986 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2323998 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2324000 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2324002 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2324004 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2324007 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2324084 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2324087 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2324090 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2324101 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2324192 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2324254 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2324257 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2324271 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2324273 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2324276 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2324323 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2324325 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2324327 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2324356 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2324358 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2324432 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2324434 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2324954 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325028 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325030 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325032 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325068 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325070 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325072 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325074 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325076 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325088 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325100 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325122 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325141 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325176 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325180 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325202 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325243 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325245 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325247 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325286 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325287 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325289 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325291 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325293 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325295 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325297 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325299 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325359 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325362 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325368 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325378 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325380 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2325382 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2326178 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2326181 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2326183 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2326185 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2326187 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327253 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327261 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327263 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327265 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327267 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327269 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327271 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327273 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327307 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327321 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327323 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327325 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327327 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327329 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327331 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327333 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327335 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327338 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327340 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327351 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327353 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327358 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327360 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2327362 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328021 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328028 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328029 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328031 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328033 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328035 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328037 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328039 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328047 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328049 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328051 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328053 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328055 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328057 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328059 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328071 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328076 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328077 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328079 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328081 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328083 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328085 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328087 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328151 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328152 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328153 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328176 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328186 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328187 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328188 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328208 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328210 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328212 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328214 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328216 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328218 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328220 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328222 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328243 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328245 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328247 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328264 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328266 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328269 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328284 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328288 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328290 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328291 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328294 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328296 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328321 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328328 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328335 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328343 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328345 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328352 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328354 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328362 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328383 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328446 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328493 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328495 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328497 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328499 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328502 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328504 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328510 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328514 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328517 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328519 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328521 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2328524 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2329037 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2329055 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2329057 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2329059 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2329083 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2329089 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2329108 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2329110 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2329112 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2329114 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2330549 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2330970 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333316 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333336 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333338 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333340 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333349 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333369 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333380 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333401 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333403 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333405 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333411 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333433 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333441 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333451 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333453 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333455 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333457 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333459 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333461 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333463 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333465 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333466 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333468 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333471 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333477 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333480 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333482 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333487 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333489 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2333491 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2334213 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2334214 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2334215 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2334287 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2334290 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2334330 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2334339 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2334348 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2334370 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2334377 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2350077 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2350083 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2350084 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2350155 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2350157 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2350159 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2350172 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2350192 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2350194 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2350196 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2350198 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2357372 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2359427 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2359428 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2359459 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2359481 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2359495 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2359544 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2359546 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2359574 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2362457 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2362459 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2362461 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2362463 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2365186 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2366658 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2368154 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2368156 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2368229 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2368231 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2369552 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2369553 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2369587 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2369591 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2369634 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2369637 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2369641 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2369647 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2369649 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2369651 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2369678 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2369700 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2369708 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2369710 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2369715 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2369747 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2369753 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2369756 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2369757 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2371030 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2371032 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2371034 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2371036 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2373867 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2373869 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2373935 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2373976 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2373978 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2373980 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2374516 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2374546 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2374548 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2374550 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2374560 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2374587 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2374592 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2374597 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2374611 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2374619 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2374724 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2374735 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2374750 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2374755 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2374756 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2375646 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2375648 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2375650 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2375652 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2375654 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2375656 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2375691 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2375719 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2375726 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2375728 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2381627 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2381640 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2381642 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382295 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382699 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382707 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382709 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382711 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382736 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382738 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382765 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382767 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382777 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382779 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382780 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382827 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382845 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382852 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382854 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382926 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382928 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382930 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382932 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382936 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382993 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2382997 (geometry probably out of source or destination SRS).
# ...
# ERROR 1: Failed to reproject feature 2435362 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435363 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435364 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435366 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435374 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435377 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435387 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435389 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435403 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435405 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435407 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435409 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435418 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435419 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435420 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435422 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435425 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435427 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435454 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435456 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435458 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435460 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435462 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435464 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435466 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435483 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435485 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435487 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435489 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435490 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435492 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435511 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2435518 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2436130 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2436132 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2436134 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2436135 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2436141 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2436143 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2436145 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2436147 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2436168 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2436721 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2436723 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2436733 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2436735 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2436781 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2436807 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2436809 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2436811 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2436813 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2436815 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2436817 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2436819 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2437033 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2439362 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2439383 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2439386 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2439388 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2446443 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2447284 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2447287 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2447289 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2447294 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2447296 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2448898 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2448912 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2449639 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2450733 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2450735 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2450737 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2450802 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2450808 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2450810 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2450811 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2450815 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2450820 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2450823 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2450824 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2450830 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2450838 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2452051 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2452060 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2452066 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2452069 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2453218 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2453236 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2453242 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2453255 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2453257 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2453338 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2453340 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2453365 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2453367 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2453369 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2453961 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2453963 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2453965 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2453967 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2454368 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2454489 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2454750 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2454752 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2454754 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2454779 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2454781 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456033 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456039 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456070 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456071 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456072 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456127 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456136 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456151 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456153 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456155 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456157 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456159 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456161 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456169 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456171 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456173 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456175 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456177 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456179 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456181 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456194 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456196 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456198 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456222 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456230 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456232 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456270 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456272 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456274 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456276 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456278 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456279 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456283 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456298 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456300 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456302 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456320 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456351 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456353 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456355 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456357 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456359 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456360 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456363 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456365 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456374 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456376 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456382 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456386 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456390 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456419 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456421 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456423 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2456428 (geometry probably out of source or destination SRS).
# ERROR 1: Failed to reproject feature 2458199 (geometry probably out of source or destination SRS).

# %% [markdown]
# ### **2.6. Importar distritos**

# %%
# !ogrinfo /home/clopez/Documentos/data/inei/censal/censo.gpkg distritos -al -so -nomd
# Out:
# INFO: Open of `/home/clopez/Documentos/data/inei/censal/censo.gpkg'
#       using driver `GPKG' successful.
#
# Layer name: distritos
# Geometry: Multi Polygon
# Feature Count: 1876
# Extent: (-81.328232, -18.350929) - (-68.652267, -0.038606)
# Layer SRS WKT:
# GEOGCRS["WGS 84",
#     ENSEMBLE["World Geodetic System 1984 ensemble",
#         MEMBER["World Geodetic System 1984 (Transit)"],
#         MEMBER["World Geodetic System 1984 (G730)"],
#         MEMBER["World Geodetic System 1984 (G873)"],
#         MEMBER["World Geodetic System 1984 (G1150)"],
#         MEMBER["World Geodetic System 1984 (G1674)"],
#         MEMBER["World Geodetic System 1984 (G1762)"],
#         MEMBER["World Geodetic System 1984 (G2139)"],
#         MEMBER["World Geodetic System 1984 (G2296)"],
#         ELLIPSOID["WGS 84",6378137,298.257223563,
#             LENGTHUNIT["metre",1]],
#         ENSEMBLEACCURACY[2.0]],
#     PRIMEM["Greenwich",0,
#         ANGLEUNIT["degree",0.0174532925199433]],
#     CS[ellipsoidal,2],
#         AXIS["geodetic latitude (Lat)",north,
#             ORDER[1],
#             ANGLEUNIT["degree",0.0174532925199433]],
#         AXIS["geodetic longitude (Lon)",east,
#             ORDER[2],
#             ANGLEUNIT["degree",0.0174532925199433]],
#     USAGE[
#         SCOPE["Horizontal component of 3D system."],
#         AREA["World."],
#         BBOX[-90,-180,90,180]],
#     ID["EPSG",4326]]
# Data axis to CRS axis mapping: 2,1
# FID Column = fid
# Geometry Column = geom
# CCDD: String (254.0)
# NOMBDEP: String (254.0)
# CCPP: String (254.0)
# NOMBPROV: String (254.0)
# CCDI: String (254.0)
# NOMBDIST: String (254.0)
# CAPITAL: String (254.0)
# UBIGEO: String (6.0)
# IDPROV: String (4.0)
# CODIGO: String (50.0)
# CNT_CCPP: Integer (0.0)
# DESCRIPCIO: String (50.0)

# %%
# !ogr2ogr -f PostgreSQL -a_srs EPSG:4326 \
 PG:"dbname=geocoding user=clopez" \
 -nln distritos \
 -nlt MULTIPOLYGON \
 -lco SCHEMA=cartografia \
 -lco GEOMETRY_NAME=geom \
 -lco SPATIAL_INDEX=GIST \
 /home/clopez/Documentos/data/inei/censal/censo.gpkg \
 -sql "SELECT FID as fid, UBIGEO as ubigeo, NOMBDIST as distrito, \
              NOMBPROV as provincia, NOMBDEP as departamento, \
              CAPITAL as capital, CCPP as ccpp, geom \
        FROM distritos"

# %% [markdown]
# validar cantidades

# %%
# !psql -U clopez -d geocoding \
 -c "SELECT 'clientes' as tabla, count(*) as cantidad from cartografia.clientes \
     UNION \
     SELECT 'barrios' as tabla, count(*) as cantidad from cartografia.barrios \
     UNION \
     SELECT 'manzanas' as tabla, count(*) as cantidad from cartografia.manzanas \
     UNION \
     SELECT 'ejes_viales' as tabla, count(*) as cantidad from cartografia.ejes_viales \
     UNION \
     SELECT 'apt' as tabla, count(*) as cantidad from cartografia.apts \
     UNION \
     SELECT 'distritos' as tabla, count(*) as cantidad from cartografia.distritos"
# Out:
#     tabla    | cantidad
# -------------+----------
#  apt         |  2458235
#  barrios     |    11528
#  clientes    |  1067373
#  distritos   |     1874
#  ejes_viales |   386542
#  manzanas    |   143418
# (6 filas)
